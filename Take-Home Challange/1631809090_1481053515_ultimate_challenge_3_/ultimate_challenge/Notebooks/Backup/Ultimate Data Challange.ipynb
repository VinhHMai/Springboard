# %% [markdown]
# Import Libraries

# %%
import json
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Files

# %%
path = 'C:/Users/vinhm/Google Drive/School Documents/Springboard/Springboard/Take-Home Challange/1631809090_1481053515_ultimate_challenge_3_/ultimate_challenge/'

# %%
file1 = open(path+'ultimate_data_challenge.json')
data1 = json.load(file1)
data1[:10]
# Out:
# [{'city': "King's Landing",
#   'trips_in_first_30_days': 4,
#   'signup_date': '2014-01-25',
#   'avg_rating_of_driver': 4.7,
#   'avg_surge': 1.1,
#   'last_trip_date': '2014-06-17',
#   'phone': 'iPhone',
#   'surge_pct': 15.4,
#   'ultimate_black_user': True,
#   'weekday_pct': 46.2,
#   'avg_dist': 3.67,
#   'avg_rating_by_driver': 5.0},
#  {'city': 'Astapor',
#   'trips_in_first_30_days': 0,
#   'signup_date': '2014-01-29',
#   'avg_rating_of_driver': 5.0,
#   'avg_surge': 1.0,
#   'last_trip_date': '2014-05-05',
#   'phone': 'Android',
#   'surge_pct': 0.0,
#   'ultimate_black_user': False,
#   'weekday_pct': 50.0,
#   'avg_dist': 8.26,
#   'avg_rating_by_driver': 5.0},
#  {'city': 'Astapor',
#   'trips_in_first_30_days': 3,
#   'signup_date': '2014-01-06',
#   'avg_rating_of_driver': 4.3,
#   'avg_surge': 1.0,
#   'last_trip_date': '2014-01-07',
#   'phone': 'iPhone',
#   'surge_pct': 0.0,
#   'ultimate_black_user': False,
#   'weekday_pct': 100.0,
#   'avg_dist': 0.77,
# ...

# %%
data1 = pd.DataFrame(data1)
data1.head()
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver
# ...

# %%
file2 = open(path+'logins.json')
data2 = json.load(file2)
data2
# Out:
# {'login_time': ['1970-01-01 20:13:18',
#   '1970-01-01 20:16:10',
#   '1970-01-01 20:16:37',
#   '1970-01-01 20:16:36',
#   '1970-01-01 20:26:21',
#   '1970-01-01 20:21:41',
#   '1970-01-01 20:12:16',
#   '1970-01-01 20:35:47',
#   '1970-01-01 20:35:38',
#   '1970-01-01 20:47:52',
#   '1970-01-01 20:26:05',
#   '1970-01-01 20:31:03',
#   '1970-01-01 20:34:46',
#   '1970-01-01 20:36:34',
#   '1970-01-01 20:39:25',
#   '1970-01-01 20:40:37',
#   '1970-01-01 20:34:58',
#   '1970-01-01 20:43:59',
#   '1970-01-01 20:47:46',
#   '1970-01-01 20:46:34',
#   '1970-01-01 20:56:07',
#   '1970-01-01 20:49:12',
#   '1970-01-01 20:59:06',
#   '1970-01-01 20:59:59',
#   '1970-01-01 21:15:01',
#   '1970-01-01 21:09:24',
#   '1970-01-01 21:19:24',
#   '1970-01-01 21:20:53',
#   '1970-01-01 21:29:19',
#   '1970-01-01 21:58:05',
#   '1970-01-01 21:51:51',
#   '1970-01-01 21:59:40',
#   '1970-01-01 22:08:34',
#   '1970-01-01 22:02:51',
#   '1970-01-01 21:58:32',
#   '1970-01-01 22:02:31',
# ...

# %%
data2 = pd.DataFrame(data2)
data2.head()
# Out:
#             login_time
# 0  1970-01-01 20:13:18
# 1  1970-01-01 20:16:10
# 2  1970-01-01 20:16:37
# 3  1970-01-01 20:16:36
# 4  1970-01-01 20:26:21

# %%
#youtube - pandas resample from data independent
data2['Login Counts'] = range(len(data2))
data2.head()
# Out:
#             login_time  Login Counts
# 0  1970-01-01 20:13:18             0
# 1  1970-01-01 20:16:10             1
# 2  1970-01-01 20:16:37             2
# 3  1970-01-01 20:16:36             3
# 4  1970-01-01 20:26:21             4

# %%
data2['login_time'] = pd.to_datetime(data2['login_time'])
data2 = data2.resample('15min', on='login_time').sum()
data2['Login Counts'] = range(len(data2))
data2.head()
# Out:
#                      Login Counts
# login_time
# 1970-01-01 20:00:00             0
# 1970-01-01 20:15:00             1
# 1970-01-01 20:30:00             2
# 1970-01-01 20:45:00             3
# 1970-01-01 21:00:00             4
